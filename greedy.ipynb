# %%
import data_generation_utils as dgu

instances = dgu.read_instances("instances.txt")
instances
# Out:
# 2 10
#
# [{'processors': 2, 'tasks': [(3, 8, 17), (3, 17, 9), (4, 1, 6), (7, 12, 13), (0, 4, 12), (1, 7, 7), (3, 18, 1), (0, 5, 8), (1, 2, 16), (5, 20, 1)]}]
# 2 10
# [{'processors': 2,
#   'tasks': [(3, 8, 17),
#    (3, 17, 9),
#    (4, 1, 6),
#    (7, 12, 13),
#    (0, 4, 12),
#    (1, 7, 7),
#    (3, 18, 1),
#    (0, 5, 8),
#    (1, 2, 16),
#    (5, 20, 1)]}]

# %%
# return {
#     "objective": 102,
#     "schedule": [
#     task 0 -> processor 1, starts at 0, finishes at 3
#         (0, 1, 0, 3),
#         (1, 2, 0, 2),
#         (2, 1, 3, 7),
#         (3, 2, 3, 5),
#         (4, 2, 5, 6)
#     ]
# }
# while arr:
#     minimum = min(arr, key=lambda x: x[1])
#     arr.remove(minimum)



def greedy(instances):
    objective = 0
    schedule = []
    
    tasks = instances.tasks
